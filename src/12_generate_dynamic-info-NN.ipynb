# %% [markdown]
# # 動的な遊びレコメンドNN用の学習データセットを作成

# %%
import pandas as pd

# %%
df_csv = pd.read_csv('/home/csv/answers_int.csv', usecols=list(range(15,19)))

# %%
df_csv
# Out:
#     現在，身体的に疲れを感じていますか？（%の値は疲労の度合いです）  現在，精神的に疲れを感じていますか？（%の値は疲労の度合いです）  \
# 0                                  3                                 3
# 1                                  5                                 5
# 2                                  4                                 4
# 3                                  2                                 3
# 4                                  4                                 4
# 5                                  3                                 3
# 6                                  2                                 1
# 7                                  5                                 5
# 8                                  4                                 4
# 9                                  4                                 4
# 10                                 3                                 4
# 11                                 3                                 0
# ...

# %%
# CSV出力
df_csv.to_csv('/home/csv/dynamic-info_data.csv', index=False)
