# %% [markdown]
# # 性格のクラスタリングで使用するデータを抽出してCSV出力する

# %%
import pandas as pd

# %%
# 数値に変換した回答結果から性格のクラスタリングに使用する部分のみを抽出
df_csv = pd.read_csv('/home/res/converted/answers_int.csv', usecols=list(range(19, 25)))

# %%
df_csv
# Out:
#     通常，自分から話を始めることはない  どちらかというと控えめで，静かな性格である  深く考えるより，すぐに行動したい  \
# 0                   1                      2                 4
# 1                   2                      4                 2
# 2                   3                      4                 3
# 3                   4                      4                 2
# 4                   4                      2                 5
# 5                   1                      3                 2
# 6                   4                      5                 3
# 7                   2                      1                 4
# 8                   5                      4                 5
# 9                   2                      4                 3
# 10                  3                      5                 3
# 11                  2                      0                 5
# 12                  2                      4                 2
# 13                  3                      3                 4
# ...

# %%
# CSV出力
df_csv.to_csv('/home/res/datasets/human_data.csv', index=False)
